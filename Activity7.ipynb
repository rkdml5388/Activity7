# %% [markdown]
# # Activity 7: Application of PCA to MNIST
# ## Relation between PCA and Autoencoder with linear activation
# - MNIST dataset consists of 60000 28x28 pixel images in 10 classes (0~9)
# - Dimenstions of datasets are Train: (55000,28,28) Test: (10000,28,28)
#
# ### _Tip> shotcuts for Jupyter Notebook_
# - Shift + Enter : run cell and select below
#
# ### _Library_
# - Tensorflow: An open source machine learning library. In this practice we will only use it to download datasets
# - Numpy: Fundamental package for array calculation
# - Matplotlib: Library for plotting
# - Sklearn: Library that contains basic classifiers
# - Time: Library for time measurement

# %% [markdown]
# ## 1.1 DownLoad data
#
# ![MNIST.png](attachment:MNIST.png)
# - MNIST(28x28 Hand written digit image) will be used from tensorflow library
# - ignore the warning message

# %%
from tensorflow.examples.tutorials.mnist import input_data
import numpy as np

mnist = input_data.read_data_sets("/tmp/data/")

X = mnist.train.images
y = mnist.train.labels
# Out:
# WARNING:tensorflow:From <ipython-input-1-af1587586c5a>:4: read_data_sets (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
# WARNING:tensorflow:From /home/dclab/.local/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:260: maybe_download (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please write your own downloading logic.
# WARNING:tensorflow:From /home/dclab/.local/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:262: extract_images (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting /tmp/data/train-images-idx3-ubyte.gz
# WARNING:tensorflow:From /home/dclab/.local/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:267: extract_labels (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting /tmp/data/train-labels-idx1-ubyte.gz
# Extracting /tmp/data/t10k-images-idx3-ubyte.gz
# Extracting /tmp/data/t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From /home/dclab/.local/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:290: DataSet.__init__ (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.

# %% [markdown]
# ## 1.2 Preprocessing
# - For each Digit, select 10 samples each

# %%
Data = X[np.argwhere(y == 0)[:10]].reshape(10,784)
for i in range(9):
    temp = X[np.argwhere(y == i+1)[:10]]
    temp = temp.reshape(10,784)
    Data = np.vstack([Data,temp])

# %% [markdown]
# ## 1.3 Visualization of the Original Data
# - Dataset is ordered in size with 10 samples each
# - Below plotting shows 0,10,20 ... 100 th images of dataset

# %%
import matplotlib.pyplot as plt
fig,axes = plt.subplots(1,10,figsize=(14,5),subplot_kw = {'xticks':[], 'yticks':[]})

for i in range(10):
    axes[i].imshow(Data[10*i].reshape([28,28]), cmap = 'gray')
fig.show()
# Out:
# /home/dclab/anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:459: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %% [markdown]
# - From sklearn.decomposition, import PCA
# - **n_components** means the **number of features for dimension-reduced dataset**

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=50)
Data_reduced = pca.fit_transform(Data)
print("Shape of Data_reduced:",np.shape(Data_reduced))
# Out:
# Shape of Data_reduced: (100, 50)

# %% [markdown]
# ## 1.4 Visualize the PCA's Input and Output
# - Sklearn provide function **pca.inverse_transform** for recover demension reduced image

# %%
import matplotlib.pyplot as plt

image = Data_reduced[50:60]
image = pca.inverse_transform(image)

fig,axes = plt.subplots(2,10,figsize=(20,5),subplot_kw = {'xticks':[], 'yticks':[]})

for i in range(10):
    temp = image[i]
    temp = temp.reshape((28,28))
    axes[0][i].imshow(temp,cmap='gray')
axes[0][4].set_title('Recovered Images',position=(0.5,1.1),fontsize=30)

for i in range(10):
    temp = Data[50+i].reshape((28,28))
    axes[1][i].imshow(temp,cmap="gray")
axes[1][4].set_title('Original Images',position=(0.5,1.1),fontsize=30)
# Out:
# Text(0.5,1.1,'Original Images')

# %% [markdown]
# ## 2 Evaluate the RMSE(Root Mean Square Error)
# - Evaluate the RMSE given,
# $$RMSE = \sqrt{\frac{1}{n}\Sigma_{i=1}^{n}{\Big(X_i -X_{reduced,i}\Big)^2}}$$ of the 100 digits n_components = 50

# %%
Data_recovered = pca.inverse_transform(Data_reduced)
np.sum(np.square(Data-Data_recovered))
# Out:
# 305.73553

# %% [markdown]
# ## 3.1 Autoencoder Design
# - Consider an autoencoder with one hidden layer and linear activation functions.
# - The number of units in the hidden layer is 50. The input to the autoencoder is the 100 digits downloaded above.
# - Observe that the outputs of the hidden layer after convergence can be identical to the results of PCA obtained above.

# %%
import tensorflow as tf
def Autoencoder(X, n_hidden):
    w_init = w_init = tf.contrib.layers.variance_scaling_initializer()
    b_init = tf.constant_initializer(0.)

    W_1 = tf.get_variable("weight1",[784,n_hidden],initializer = w_init)
    b_1 = tf.get_variable("bias1",[n_hidden], initializer = b_init)

    h1 = tf.matmul(X,W_1) + b_1

    W_2 = tf.get_variable("weight2",[n_hidden,784], initializer = w_init)
    b_2 = tf.get_variable("bias2",[784], initializer = b_init)

    X_pred = tf.matmul(h1,W_2) + b_2

    loss = tf.reduce_sum(tf.square(X_pred-X))
    return loss, X_pred

# %% [markdown]
# ## 3.2 Hyperparameter Tuning
# - n_hidden: number of hidden layer units
# - learning_rate: learning rate of optimizer

# %%
n_hidden = 50
learning_rate = 0.00001

# %%
X = tf.placeholder(tf.float32,[None,784])

loss,X_pred = Autoencoder(X,n_hidden)
optimizer = tf.train.AdamOptimizer(learning_rate).minimize(loss)

# %%
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    for i in range(300000):
        _loss, _ = sess.run([loss,optimizer], feed_dict = {X: Data})
        if i%2000 == 0:
            print("Epoch:",i,"Sum of Squared Error:",_loss)
    Recovered = sess.run(X_pred, feed_dict = {X: Data[50:60]})

# %% [markdown]
# ## 3.3 Visualize the Autoencoder's Input and Output
# - Use above cell to visualize recovered image
